# %% [markdown]
# <a href="https://colab.research.google.com/github/KGzB/CAS-Applied-Data-Science/blob/master/Module-2/CAS-D1-DescriptiveStatistics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Notebook 1, Module 2, Statistical Inference for Data Science, CAS Applied Data Science, 2024-08-27, A. Mühlemann, University of Bern.
#
# *This notebook is based on the notebook by S. Haug and G. Conti from 2020*

# %% [markdown]
# # 1. Descriptive Statistics on Single Features

# %% [markdown]
# **Goals**
# - Graphical preparation of the data
# - Calculate summary statistics

# %% [markdown]
# First load the necessary libraries / modules.

# %%
# Load the needed python libraries by executing this python code (press ctrl enter)
import numpy as np
import scipy.stats
import matplotlib.pyplot as plt
import pandas as pd
import io

# %% [markdown]
# In this notebook we will look at a dataset about the effect of surface and vision on balance (source https://gksmyth.github.io/ozdasl/oz/ctsib.html).
#
# The balance of subjects were observed on two different surfaces and for restricted and unrestricted vision.
#
# - *Subject*: id of subject-
# - *Sex*: male or female
# - *Age*: age in years
# - *Height*: height in cm
# - *Weight*:	weight in kg
# -	*Surface*: normal or foam
# - *Vision*:	eyes open, eyes closed, or closed dome
# -	*CTSIB*: Qualitive measure of balance, 1 (stable) - 4 (unstable)
#
# I uploaded the dataset to Github so that we can read it directly from there.

# %%
url = "https://github.com/KGzB/CAS-Applied-Data-Science/blob/master/Module-2/balance.csv?raw=true"
df = pd.read_csv(url, sep=";")
#df = pd.set_option(r'display.max_rows', 480)
df
# Out:
#      Subject     Sex  Age  Height  Weight Surface  Vision  CTSIB
# 0          1    male   22   176.0    68.2    norm    open      1
# 1          1    male   22   176.0    68.2    norm    open      1
# 2          1    male   22   176.0    68.2    norm  closed      2
# 3          1    male   22   176.0    68.2    norm  closed      2
# 4          1    male   22   176.0    68.2    norm    dome      1
# 5          1    male   22   176.0    68.2    norm    dome      2
# 6          1    male   22   176.0    68.2    foam    open      2
# 7          1    male   22   176.0    68.2    foam    open      2
# 8          1    male   22   176.0    68.2    foam  closed      2
# 9          1    male   22   176.0    68.2    foam  closed      2
# 10         1    male   22   176.0    68.2    foam    dome      2
# 11         1    male   22   176.0    68.2    foam    dome      2
# 12         2    male   22   181.0    67.6    norm    open      1
# 13         2    male   22   181.0    67.6    norm    open      1
# 14         2    male   22   181.0    67.6    norm  closed      2
# 15         2    male   22   181.0    67.6    norm  closed      2
# 16         2    male   22   181.0    67.6    norm    dome      2
# 17         2    male   22   181.0    67.6    norm    dome      2
# 18         2    male   22   181.0    67.6    foam    open      2
# 19         2    male   22   181.0    67.6    foam    open      2
# 20         2    male   22   181.0    67.6    foam  closed      3
# 21         2    male   22   181.0    67.6    foam  closed      3
# 22         2    male   22   181.0    67.6    foam    dome      3
# 23         2    male   22   181.0    67.6    foam    dome      3
# 24         3    male   22   175.5    72.0    norm    open      2
# 25         3    male   22   175.5    72.0    norm    open      2
# 26         3    male   22   175.5    72.0    norm  closed      2
# 27         3    male   22   175.5    72.0    norm  closed      2
# 28         3    male   22   175.5    72.0    norm    dome      2
# 29         3    male   22   175.5    72.0    norm    dome      2
# 30         3    male   22   175.5    72.0    foam    open      2
# 31         3    male   22   175.5    72.0    foam    open      2
# 32         3    male   22   175.5    72.0    foam  closed      3
# 33         3    male   22   175.5    72.0    foam  closed      3
# 34         3    male   22   175.5    72.0    foam    dome      2
# 35         3    male   22   175.5    72.0    foam    dome      3
# 36         4    male   21   180.0    73.2    norm    open      1
# 37         4    male   21   180.0    73.2    norm    open      2
# 38         4    male   21   180.0    73.2    norm  closed      2
# 39         4    male   21   180.0    73.2    norm  closed      2
# 40         4    male   21   180.0    73.2    norm    dome      2
# 41         4    male   21   180.0    73.2    norm    dome      2
# 42         4    male   21   180.0    73.2    foam    open      2
# 43         4    male   21   180.0    73.2    foam    open      2
# 44         4    male   21   180.0    73.2    foam  closed      3
# 45         4    male   21   180.0    73.2    foam  closed      3
# 46         4    male   21   180.0    73.2    foam    dome      3
# 47         4    male   21   180.0    73.2    foam    dome      3
# 48         5  female   20   166.0    63.8    norm    open      1
# 49         5  female   20   166.0    63.8    norm    open      2
# 50         5  female   20   166.0    63.8    norm  closed      2
# 51         5  female   20   166.0    63.8    norm  closed      2
# 52         5  female   20   166.0    63.8    norm    dome      3
# 53         5  female   20   166.0    63.8    norm    dome      2
# 54         5  female   20   166.0    63.8    foam    open      2
# 55         5  female   20   166.0    63.8    foam    open      2
# 56         5  female   20   166.0    63.8    foam  closed      3
# 57         5  female   20   166.0    63.8    foam  closed      3
# 58         5  female   20   166.0    63.8    foam    dome      3
# 59         5  female   20   166.0    63.8    foam    dome      3
# 60         6    male   18   177.0    78.8    norm    open      1
# 61         6    male   18   177.0    78.8    norm    open      1
# 62         6    male   18   177.0    78.8    norm  closed      1
# 63         6    male   18   177.0    78.8    norm  closed      1
# 64         6    male   18   177.0    78.8    norm    dome      1
# 65         6    male   18   177.0    78.8    norm    dome      2
# 66         6    male   18   177.0    78.8    foam    open      2
# 67         6    male   18   177.0    78.8    foam    open      2
# 68         6    male   18   177.0    78.8    foam  closed      2
# 69         6    male   18   177.0    78.8    foam  closed      2
# 70         6    male   18   177.0    78.8    foam    dome      2
# 71         6    male   18   177.0    78.8    foam    dome      2
# 72         7    male   29   183.0    86.4    norm    open      1
# 73         7    male   29   183.0    86.4    norm    open      1
# 74         7    male   29   183.0    86.4    norm  closed      2
# 75         7    male   29   183.0    86.4    norm  closed      2
# 76         7    male   29   183.0    86.4    norm    dome      2
# 77         7    male   29   183.0    86.4    norm    dome      2
# 78         7    male   29   183.0    86.4    foam    open      2
# 79         7    male   29   183.0    86.4    foam    open      2
# 80         7    male   29   183.0    86.4    foam  closed      2
# 81         7    male   29   183.0    86.4    foam  closed      2
# 82         7    male   29   183.0    86.4    foam    dome      2
# 83         7    male   29   183.0    86.4    foam    dome      2
# 84         8  female   22   150.0    44.6    norm    open      1
# 85         8  female   22   150.0    44.6    norm    open      1
# 86         8  female   22   150.0    44.6    norm  closed      2
# 87         8  female   22   150.0    44.6    norm  closed      2
# 88         8  female   22   150.0    44.6    norm    dome      2
# 89         8  female   22   150.0    44.6    norm    dome      2
# 90         8  female   22   150.0    44.6    foam    open      2
# 91         8  female   22   150.0    44.6    foam    open      2
# 92         8  female   22   150.0    44.6    foam  closed      3
# 93         8  female   22   150.0    44.6    foam  closed      3
# 94         8  female   22   150.0    44.6    foam    dome      2
# 95         8  female   22   150.0    44.6    foam    dome      2
# 96         9  female   29   154.0    57.8    norm    open      1
# 97         9  female   29   154.0    57.8    norm    open      1
# 98         9  female   29   154.0    57.8    norm  closed      2
# 99         9  female   29   154.0    57.8    norm  closed      2
# 100        9  female   29   154.0    57.8    norm    dome      2
# 101        9  female   29   154.0    57.8    norm    dome      2
# 102        9  female   29   154.0    57.8    foam    open      2
# 103        9  female   29   154.0    57.8    foam    open      2
# 104        9  female   29   154.0    57.8    foam  closed      3
# 105        9  female   29   154.0    57.8    foam  closed      3
# 106        9  female   29   154.0    57.8    foam    dome      3
# 107        9  female   29   154.0    57.8    foam    dome      3
# 108       10    male   31   176.5    80.8    norm    open      1
# 109       10    male   31   176.5    80.8    norm    open      1
# 110       10    male   31   176.5    80.8    norm  closed      2
# 111       10    male   31   176.5    80.8    norm  closed      2
# 112       10    male   31   176.5    80.8    norm    dome      1
# 113       10    male   31   176.5    80.8    norm    dome      1
# 114       10    male   31   176.5    80.8    foam    open      2
# 115       10    male   31   176.5    80.8    foam    open      2
# 116       10    male   31   176.5    80.8    foam  closed      2
# 117       10    male   31   176.5    80.8    foam  closed      2
# 118       10    male   31   176.5    80.8    foam    dome      2
# 119       10    male   31   176.5    80.8    foam    dome      2
# 120       11    male   24   176.0    91.0    norm    open      1
# 121       11    male   24   176.0    91.0    norm    open      1
# 122       11    male   24   176.0    91.0    norm  closed      2
# 123       11    male   24   176.0    91.0    norm  closed      2
# 124       11    male   24   176.0    91.0    norm    dome      2
# 125       11    male   24   176.0    91.0    norm    dome      2
# 126       11    male   24   176.0    91.0    foam    open      2
# 127       11    male   24   176.0    91.0    foam    open      2
# 128       11    male   24   176.0    91.0    foam  closed      3
# 129       11    male   24   176.0    91.0    foam  closed      3
# 130       11    male   24   176.0    91.0    foam    dome      2
# 131       11    male   24   176.0    91.0    foam    dome      2
# 132       12    male   33   184.0    89.8    norm    open      1
# 133       12    male   33   184.0    89.8    norm    open      1
# 134       12    male   33   184.0    89.8    norm  closed      2
# 135       12    male   33   184.0    89.8    norm  closed      2
# 136       12    male   33   184.0    89.8    norm    dome      2
# 137       12    male   33   184.0    89.8    norm    dome      2
# 138       12    male   33   184.0    89.8    foam    open      2
# 139       12    male   33   184.0    89.8    foam    open      2
# 140       12    male   33   184.0    89.8    foam  closed      2
# 141       12    male   33   184.0    89.8    foam  closed      2
# 142       12    male   33   184.0    89.8    foam    dome      3
# 143       12    male   33   184.0    89.8    foam    dome      2
# 144       13    male   18   187.0    85.0    norm    open      1
# 145       13    male   18   187.0    85.0    norm    open      1
# 146       13    male   18   187.0    85.0    norm  closed      2
# 147       13    male   18   187.0    85.0    norm  closed      2
# 148       13    male   18   187.0    85.0    norm    dome      2
# 149       13    male   18   187.0    85.0    norm    dome      2
# 150       13    male   18   187.0    85.0    foam    open      2
# 151       13    male   18   187.0    85.0    foam    open      2
# 212       18  female   34   170.0    67.8    foam  closed      2
# 213       18  female   34   170.0    67.8    foam  closed      2
# 214       18  female   34   170.0    67.8    foam    dome      2
# 215       18  female   34   170.0    67.8    foam    dome      2
# 216       19    male   18   190.0    78.6    norm    open      1
# 217       19    male   18   190.0    78.6    norm    open      1
# 218       19    male   18   190.0    78.6    norm  closed      1
# 219       19    male   18   190.0    78.6    norm  closed      2
# 220       19    male   18   190.0    78.6    norm    dome      2
# 221       19    male   18   190.0    78.6    norm    dome      2
# 222       19    male   18   190.0    78.6    foam    open      2
# 223       19    male   18   190.0    78.6    foam    open      2
# 224       19    male   18   190.0    78.6    foam  closed      2
# 225       19    male   18   190.0    78.6    foam  closed      2
# 226       19    male   18   190.0    78.6    foam    dome      2
# 227       19    male   18   190.0    78.6    foam    dome      2
# 228       20    male   30   168.5    64.2    norm    open      1
# 229       20    male   30   168.5    64.2    norm    open      1
# 230       20    male   30   168.5    64.2    norm  closed      1
# 231       20    male   30   168.5    64.2    norm  closed      1
# 232       20    male   30   168.5    64.2    norm    dome      2
# 233       20    male   30   168.5    64.2    norm    dome      2
# 234       20    male   30   168.5    64.2    foam    open      2
# 235       20    male   30   168.5    64.2    foam    open      2
# 236       20    male   30   168.5    64.2    foam  closed      3
# 237       20    male   30   168.5    64.2    foam  closed      3
# 238       20    male   30   168.5    64.2    foam    dome      3
# 239       20    male   30   168.5    64.2    foam    dome      3
# 240       21  female   19   167.5    69.4    norm    open      1
# 241       21  female   19   167.5    69.4    norm    open      1
# 242       21  female   19   167.5    69.4    norm  closed      2
# 243       21  female   19   167.5    69.4    norm  closed      2
# 244       21  female   19   167.5    69.4    norm    dome      1
# 245       21  female   19   167.5    69.4    norm    dome      1
# 246       21  female   19   167.5    69.4    foam    open      2
# 247       21  female   19   167.5    69.4    foam    open      2
# 248       21  female   19   167.5    69.4    foam  closed      2
# 249       21  female   19   167.5    69.4    foam  closed      2
# 250       21  female   19   167.5    69.4    foam    dome      2
# 251       21  female   19   167.5    69.4    foam    dome      2
# 252       22  female   20   167.0    50.0    norm    open      1
# 253       22  female   20   167.0    50.0    norm    open      2
# 254       22  female   20   167.0    50.0    norm  closed      2
# 255       22  female   20   167.0    50.0    norm  closed      2
# 256       22  female   20   167.0    50.0    norm    dome      2
# 257       22  female   20   167.0    50.0    norm    dome      2
# 258       22  female   20   167.0    50.0    foam    open      2
# 259       22  female   20   167.0    50.0    foam    open      2
# 260       22  female   20   167.0    50.0    foam  closed      3
# 261       22  female   20   167.0    50.0    foam  closed      3
# 262       22  female   20   167.0    50.0    foam    dome      3
# 263       22  female   20   167.0    50.0    foam    dome      3
# 264       23    male   36   184.0   102.4    norm    open      1
# 265       23    male   36   184.0   102.4    norm    open      1
# 266       23    male   36   184.0   102.4    norm  closed      2
# 267       23    male   36   184.0   102.4    norm  closed      2
# 268       23    male   36   184.0   102.4    norm    dome      2
# 269       23    male   36   184.0   102.4    norm    dome      2
# 270       23    male   36   184.0   102.4    foam    open      2
# 271       23    male   36   184.0   102.4    foam    open      2
# 391       33  female   35   159.0    53.0    foam    open      2
# 392       33  female   35   159.0    53.0    foam  closed      3
# 393       33  female   35   159.0    53.0    foam  closed      3
# 394       33  female   35   159.0    53.0    foam    dome      2
# 395       33  female   35   159.0    53.0    foam    dome      3
# 396       34    male   28   172.0    74.0    norm    open      1
# 397       34    male   28   172.0    74.0    norm    open      2
# 398       34    male   28   172.0    74.0    norm  closed      2
# 399       34    male   28   172.0    74.0    norm  closed      1
# 400       34    male   28   172.0    74.0    norm    dome      2
# 401       34    male   28   172.0    74.0    norm    dome      2
# 402       34    male   28   172.0    74.0    foam    open      2
# 403       34    male   28   172.0    74.0    foam    open      2
# 404       34    male   28   172.0    74.0    foam  closed      2
# 405       34    male   28   172.0    74.0    foam  closed      2
# 406       34    male   28   172.0    74.0    foam    dome      2
# 407       34    male   28   172.0    74.0    foam    dome      2
# 408       35    male   24   177.0    89.8    norm    open      1
# 409       35    male   24   177.0    89.8    norm    open      1
# 410       35    male   24   177.0    89.8    norm  closed      1
# 411       35    male   24   177.0    89.8    norm  closed      1
# 412       35    male   24   177.0    89.8    norm    dome      1
# 413       35    male   24   177.0    89.8    norm    dome      1
# 414       35    male   24   177.0    89.8    foam    open      2
# 415       35    male   24   177.0    89.8    foam    open      2
# 416       35    male   24   177.0    89.8    foam  closed      2
# 417       35    male   24   177.0    89.8    foam  closed      2
# 418       35    male   24   177.0    89.8    foam    dome      2
# 419       35    male   24   177.0    89.8    foam    dome      2
# 420       36  female   19   167.0    60.2    norm    open      1
# 421       36  female   19   167.0    60.2    norm    open      1
# 422       36  female   19   167.0    60.2    norm  closed      2
# 423       36  female   19   167.0    60.2    norm  closed      2
# 424       36  female   19   167.0    60.2    norm    dome      2
# 425       36  female   19   167.0    60.2    norm    dome      2
# 426       36  female   19   167.0    60.2    foam    open      2
# 427       36  female   19   167.0    60.2    foam    open      2
# 428       36  female   19   167.0    60.2    foam  closed      3
# 429       36  female   19   167.0    60.2    foam  closed      3
# 430       36  female   19   167.0    60.2    foam    dome      3
# 431       36  female   19   167.0    60.2    foam    dome      3
# 432       37  female   37   167.0    62.2    norm    open      2
# 433       37  female   37   167.0    62.2    norm    open      2
# 434       37  female   37   167.0    62.2    norm  closed      2
# 435       37  female   37   167.0    62.2    norm  closed      2
# 436       37  female   37   167.0    62.2    norm    dome      2
# 437       37  female   37   167.0    62.2    norm    dome      2
# 438       37  female   37   167.0    62.2    foam    open      2
# 439       37  female   37   167.0    62.2    foam    open      2
# 440       37  female   37   167.0    62.2    foam  closed      3
# 441       37  female   37   167.0    62.2    foam  closed      3
# 442       37  female   37   167.0    62.2    foam    dome      2
# 443       37  female   37   167.0    62.2    foam    dome      2
# 444       38  female   24   173.0    81.4    norm    open      2
# 445       38  female   24   173.0    81.4    norm    open      2
# 446       38  female   24   173.0    81.4    norm  closed      2
# 447       38  female   24   173.0    81.4    norm  closed      2
# 448       38  female   24   173.0    81.4    norm    dome      2
# 449       38  female   24   173.0    81.4    norm    dome      2
# 450       38  female   24   173.0    81.4    foam    open      2
# 451       38  female   24   173.0    81.4    foam    open      2
# 452       38  female   24   173.0    81.4    foam  closed      3
# 453       38  female   24   173.0    81.4    foam  closed      4
# 454       38  female   24   173.0    81.4    foam    dome      3
# 455       38  female   24   173.0    81.4    foam    dome      3
# 456       39  female   20   170.0    66.2    norm    open      1
# 457       39  female   20   170.0    66.2    norm    open      1
# 458       39  female   20   170.0    66.2    norm  closed      2
# 459       39  female   20   170.0    66.2    norm  closed      2
# 460       39  female   20   170.0    66.2    norm    dome      2
# 461       39  female   20   170.0    66.2    norm    dome      2
# 462       39  female   20   170.0    66.2    foam    open      2
# 463       39  female   20   170.0    66.2    foam    open      2
# 464       39  female   20   170.0    66.2    foam  closed      2
# 465       39  female   20   170.0    66.2    foam  closed      2
# 466       39  female   20   170.0    66.2    foam    dome      2
# 467       39  female   20   170.0    66.2    foam    dome      3
# 468       40  female   22   164.0    65.0    norm    open      1
# 469       40  female   22   164.0    65.0    norm    open      2
# 470       40  female   22   164.0    65.0    norm  closed      2
# 471       40  female   22   164.0    65.0    norm  closed      2
# 472       40  female   22   164.0    65.0    norm    dome      2
# 473       40  female   22   164.0    65.0    norm    dome      2
# 474       40  female   22   164.0    65.0    foam    open      2
# 475       40  female   22   164.0    65.0    foam    open      2
# 476       40  female   22   164.0    65.0    foam  closed      2
# 477       40  female   22   164.0    65.0    foam  closed      2
# 478       40  female   22   164.0    65.0    foam    dome      2
# 479       40  female   22   164.0    65.0    foam    dome      2

# %% [markdown]
# ## 1.1 Graphical Analyis
# ### 1.1.1 Pie chart and bar plot (categorical variables)
# Pie charts are used to show proportions of a whole.
#
# We could, for example, ask ourselves about how the genders were represented in this study percentage-wise. When we look at the dataset more closely we can see that each participant participated in different experiments. Thus, it probably would make sense to first get a subdataframe with just the distinct individuals.

# %%
# Pie chart of the gender distribution
gender_counts = df['Sex'].value_counts() # Counts the frequency of males and females from the table
plt.pie(gender_counts.values, labels=gender_counts.index, autopct= '%1.1f%%', startangle= 90)
plt.title("Gender Distribution")
plt.show()

# %% [markdown]
# The problem with pie charts is that if there are many groups we tend missinterpret the pie slices (https://www.data-to-viz.com/caveat/pie.html). Thus, it often is reasonable sense to use a barplot instead.

# %%
# Barplot of the gender distribution
gender_counts = df['Sex'].value_counts() # counts the number of sex from the table
plt.bar(gender_counts.index, gender_counts.values)
plt.xlabel('Gender')
plt.ylabel('Count')
plt.title("Gender Distribution")
plt.legend("Sex")
plt.show()

# %% [markdown]
# ## 1.1.2 Histogram (numerical variables)
# Histograms are used to display frequencies or proportions.
#
# To get a better idea about our participants we would like to look at their age distribution using a histogram.

# %%
# histogram of age distibtion
df['Age'].plot(kind = 'hist', fill = True, histtype = 'step', label = 'lifespan', color = 'Skyblue')
plt.legend() # Labels of the table
plt.show()

# %% [markdown]
# The authors mention
# "for both males and females, ten older (more than 24 years old) and ten younger subjects were selected".
# This can be seen in this histogramm (at least that when not considering the genders yet)

# %% [markdown]
# Let us now check whether this is fulfilled for each gender.

# %%
# Create a histogram for each gender
for sex in df['Sex'].unique(): # Loops over the genders in the list
  df[df['Sex'] == sex]['Age'].plot(kind = 'hist', fill = True, histtype = 'step', label = sex, color = 'skyblue')
  plt.title(f'Age Distribution for {sex}')
  plt.xlabel('Age')
  plt.ylabel('Frequency')
  plt.legend()
  plt.show()

# %% [markdown]
# ### Kernel Density Estimation
# Kernel Density Estimation is a method for visualizing the distribution of a dataset by creating a smooth curve. An advantage of using KDE over a histogram is that it produces a continuous, smooth curve that is not dependent on the bin size. This can provide a clearer picture of the underlying data distribution, especially with smaller datasets, and can reveal multimodality (multiple peaks) that might be hidden by a histogram's fixed binning. Its primary drawback is that its appearance is highly dependent on a parameter called the "bandwidth," which can be difficult to choose, and a poor choice can lead to a misleading representation of the data. *Please play around with the bandwidth to see its effect.*

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.neighbors import KernelDensity

# create a kernel density estimate for the paricipants age
age_data = df['Age'].values.reshape(-1, 1)
kde = KernelDensity(bandwidth=3.0, kernel='gaussian')
kde.fit(age_data)

# range for plotting
age_range = np.linspace(df['Age'].min() - 5, df['Age'].max() + 5, 1000).reshape(-1, 1)

# Get the density
log_density_gaussian = kde.score_samples(age_range)
density_gaussian = np.exp(log_density_gaussian)

# Plot the KDE
plt.figure(figsize=(10, 6))
plt.plot(age_range, density_gaussian, label='Gaussian Kernel', color='blue', linewidth=2)

# Add histogram
plt.hist(df['Age'], density=True, alpha=0.6, color='grey', label='Histogram of Data')

plt.title('Kernel Density Estimation of Participant Age')
plt.xlabel('Age')
plt.ylabel('Density')
plt.show()

# %% [markdown]
# Try to draw the densities for the males and females in the same plot.

# %%
# Scatter plot of Height and Weight colored with respect to gender
males = df[df['Sex'] == 'male']['Age'].values.reshape(-1, 1)
females = df[df['Sex'] == 'female']['Age'].values.reshape(-1, 1)

# plot range
age_range = np.linspace(df['Age'].min() - 5, df['Age'].max() + 5, 1000).reshape(-1, 1)

# fit males
kde_males = KernelDensity(bandwidth=3.0, kernel='gaussian')
kde_males.fit(males)
log_density_males = kde_males.score_samples(age_range)
density_males = np.exp(log_density_males)

# fit females
kde_females = KernelDensity(bandwidth=3.0, kernel='gaussian')
kde_females.fit(females)
log_density_females = kde_females.score_samples(age_range)
density_females = np.exp(log_density_females)

# Plot both KDE curves on the same plot
plt.figure(figsize=(10, 6))
plt.plot(age_range, density_males, label='Males', color='blue', linewidth=2)
plt.plot(age_range, density_females, label='Females', color='red', linewidth=2)

plt.title('KDE of Age by Gender')
plt.xlabel('Age')
plt.ylabel('Density')
plt.legend()
plt.show()

# %% [markdown]
# ### 1.1.3 Scatter plot colored by gender (simulatneous description)
#
# Scatter plots use dots to represent values for two different numeric variables.
#
# For example, we could look at the species and one of the numerical characteristics simulatneously.
#
# It is reasonable to assume that taller people tend to be heavier. We would like to check whether this assumption is fulfilled in our dataset. To differentiate between the genders we can color the dots with respect to the genders.

# %%
# Create colors for genders
colors = {'male': 'blue', 'female': 'red'}

# Create a scatter plot
for gender in df['Sex'].unique():
    subset = df[df['Sex'] == gender]
    plt.scatter(subset['Height'], subset['Weight'], color=colors[gender], label=gender, s=100, alpha=0.7)

# show plot
plt.title('Height vs. Weight')
plt.xlabel('Height')
plt.ylabel('Weight')
plt.legend(title='Gender')

# %% [markdown]
# What can you see in this picture?

# %% [markdown]
# # 1.2 Numerical analysis
#
# # 1.2.1 Location
#
# Location measures are used to describe typical values of a variable. Best known are the mean and the median.

# %%
# Mean of numerical variables of participants
df[['Age', 'Height', 'Weight']].mean()
# Out:
# Age        26.800
# Height    172.050
# Weight     71.145
# dtype: float64

# %% [markdown]
# Maybe it would make sense to group by gender.

# %%
# Mean of numerical variables of participants grouped by gender
participants = df.groupby('Sex')
df[['Age', 'Height', 'Weight']].mean()
# Out:
# Age        26.800
# Height    172.050
# Weight     71.145
# dtype: float64

# %%
# Median of numerical variables on participants grouped by Sex
df[['Age', 'Height', 'Weight']].median()
# Out:
# Age        25.5
# Height    173.0
# Weight     68.0
# dtype: float64

# %% [markdown]
# What do you notice when you compare the mean with the median?
#
# ## 1.2.2 Spread
#
# Typical values are interesting but sometimes more information is needed. It is for example also of interest to see how spead the values are. Typical measures for the spread are the variance, standard deviation, inter quartile range, etc.

# %%
# Standard deviation of numerical variables on participants grouped by Sex
df[['Age', 'Height', 'Weight']].std()
# Out:
# Age        6.355640
# Height    10.472631
# Weight    15.394665
# dtype: float64

# %% [markdown]
# Which variable has the most standard deviation? would you have expected that?
#
# We can also look at the IQR.

# %%
# IQR of Weight
df['Weight'].quantile(0.75) - df['Weight'].quantile(0.25)
# Out:
# np.float64(22.85)

# %% [markdown]
# Compare the standard deviation of *Weight* with its IQR.

# %% [markdown]
# Alternatively, one can also get most of those measures with a single command:

# %%
participants = df[['Subject', 'Sex', 'Age', 'Height',	'Weight']].drop_duplicates()
grouped_participants = participants.groupby('Sex')
grouped_participants[['Age', 'Height',	'Weight']].describe()
# Out:
#          Age                                               Height          \
#        count  mean       std   min   25%   50%   75%   max  count    mean
# Sex
# female  20.0  26.9  6.742637  19.0  20.0  25.5  34.0  37.0   20.0  164.05
# male    20.0  26.7  6.275265  18.0  22.0  26.0  31.0  38.0   20.0  180.05
#
#         ...               Weight                                            \
#         ...    75%    max  count   mean        std   min   25%   50%   75%
# Sex     ...
# female  ...  168.5  174.5   20.0  59.41   9.460939  44.2  52.5  60.5  65.2
# male    ...  184.0  190.0   20.0  82.88  10.884542  64.2  73.8  84.0  89.8
#
#
#           max
# Sex
# female   81.4
# male    102.4
#
# [2 rows x 24 columns]

# %% [markdown]
# However, this output is not very comprehensible. Here it makes more sense to consider only one species for the summary:

# %%
grouped_participants['Weight'].describe()
# Out:
#         count   mean        std   min   25%   50%   75%    max
# Sex
# female   20.0  59.41   9.460939  44.2  52.5  60.5  65.2   81.4
# male     20.0  82.88  10.884542  64.2  73.8  84.0  89.8  102.4

# %% [markdown]
# Do all these digits after the comma make sense?

# %% [markdown]
# ## 1.2.3 Shape
#
# Another measure that is often looked at is the shape of the distribution. The mostly used measures are the skewness and the kurtosis.

# %%
# Skew of numerical variables on participants grouped by Sex
df[['Age', 'Height','Weight']].skew()
# Out:
# Age       0.238092
# Height   -0.615889
# Weight    0.156073
# dtype: float64

# %% [markdown]
# The skewness of *Height* is $<0$ for both genders. What does that mean?

# %% [markdown]
# Now let us look at the kurtosis.

# %%
# Kurtosis of numerical variables on participants grouped by Sex
df[['Age', 'Height',    'Weight']].kurt(numeric_only=True)
# Out:
# Age      -1.354492
# Height    0.295308
# Weight   -0.782808
# dtype: float64

# %% [markdown]
# The idea behind the kurtosis is the following:
# Some numerical characteristics, when the sample size is large and the intervals are small, result in a histogram that resembles a Gaussian bell curve. In this case, the value of the kurtosis is close to zero. If the tails are heavier than you would expect for a Gaussian distribution the kurtosis will be substantially positive. If the tails are less heavy than you would expect for a Gaussian distribution the kurtosis will be negative.

# %% [markdown]
# ## 1.7 Outlook
# A often used example of a normal distribtion is the height distribtion in a population. Let us check, whether this could also be the case for our data set.
#
# When looking at hypothesis testing, we will see how to test this mathematically.
#
# Our model is a normal distribution with the mean and width taken from the dataset: **norm.pdf(x,mean,width)**.

# %%
from scipy.stats import norm

# Get mean and std from height

mean  = df['Height'].mean()
std = df['Height'].std()
print(mean,std)

# Create gaussian pdf
xmin = df['Height'].min()
xmax = df['Height'].max()
x = np.linspace(xmin, xmax, 100)
pdf = norm.pdf(x, mean, std)

# Plot histogram
plt.hist(df['Height'], density=True, alpha=0.6, color='skyblue', edgecolor='black', label=' Histogram')
plt.plot(x, pdf, 'r', linewidth=2, label='Normal Distribution')
plt.show()
# Out:
# 172.05 10.472630598339146

# %% [markdown]
# What do you think?

# %% [markdown]
# # 2. Simultaneous Description of two Features

# %% [markdown]
# In the first part of this notebook, we only looked at individual characteristics. For example, we calculated the mean *slength* of *iris setosa*. Of course, we did this simultaneously for all characteristics and species, but we never compared two characteristics directly. That is what we would like to do now.

# %% [markdown]
# ## 2.1 Graphical Analysis
#
# ### 2.1.1 Boxplots
#
# A boxplot is a graphical display of the minimum, maximum, and the 3 quartiles.
#
# We could for example look at the difference in balance scores depending on the surface the participants stand on. Let us first consider the case when the particiants view is not obstructed.

# %%
# Boxplots of CTSIB-score for the two different surfaces.
tmp = df[df['Vision']=='open'][['Surface', 'CTSIB']]
tmp.pivot(columns='Surface', values='CTSIB').boxplot()
# Out:
# <Axes: >

# %% [markdown]
# Would you expect the boxplots to look like this? Inspect the dataset more closely.
#
# We could also look at the height distribution according to the genders.

# %%
# Boxplots of height for the genders.
tmp = df[['Sex', 'Height']]
tmp.pivot(columns='Sex', values='Height').boxplot()
# Out:
# <Axes: >

# %% [markdown]
# ### 2.1.2 Scatter matrix
#
# Now let us see whether some of the numerical infos on the participants correlate.  (https://pandas.pydata.org/pandas-docs/stable/generated/pandas.plotting.scatter_matrix.html)

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(df[['Age','Height','Weight']], alpha=0.2, diagonal='hist')
plt.show()

# %% [markdown]
# As we would have assumed there is a positive correlation between height and weight.

# %% [markdown]
# ## 2.2 Numerical Analyis
#
# ### 2.3 Correlation
# To get more information on the correlation between two variables the correlation coefficient is calculated.
#
# Let's see whether the correlation coefficient does support this observation.
#
# **Caution**: correlation not equals causation!!

# %%
# Correlation (Pearson) of Age, Height and Weight
df[['Age','Height','Weight']].corr()
# Out:
#              Age    Height    Weight
# Age     1.000000  0.031014  0.100257
# Height  0.031014  1.000000  0.815839
# Weight  0.100257  0.815839  1.000000

# %% [markdown]
# What is the definition of the correlation?

# %% [markdown]
# What kind of relationship between *Age* and *Height* does the correlation coefficient suggest?

# %% [markdown]
# ### Exercise
# We have now seen several examples of desciptive approaches. What we have left out so far is to really investigate the difference in balance depending of *Surface* and *Vision*. User the remaining time to further investigate!
