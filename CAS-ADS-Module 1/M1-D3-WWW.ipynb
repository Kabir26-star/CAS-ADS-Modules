# %% [markdown]
# Notebook 1, Module 1, Data and Data Management, CAS Applied Data Science, 2024-08-23, A. Mühlemann, University of Bern. (based on the template by S. Haug)

# %% [markdown]
# # 3. Data acquisition on the world wide web
#
# **Learning outcomes:**
#
# Participants will be able to collect data from www sources. Examples are provided and exercised. We have about 1.5h hours for this tutorial.
#
# **Table of Contents**
# - 3.1 Read json from the web
# - 3.2 Retrieve and display pictures and files from the web
# - 3.3 Scraping webpages (html scraping)
# - 3.4 Cron jobs and Scheduled tasks
# - Some notes and links concerning social media
#
# **Further sources**
# - Examples all over internet
# - A book: https://www.packtpub.com/big-data-and-business-intelligence/mastering-social-media-mining-python

# %% [markdown]
# ## 3.1 Analyse Aare with data from https://aareguru.existenz.ch/

# %% [markdown]
# Get the data from website, bring it into a format which can be imported into a dataframe, plot the time series and the histograms.

# %%
import requests
import pandas as pd
from datetime import datetime

# URL of the Aare Guru API only getting infos from bern
url = 'https://aareguru.existenz.ch/v2018/current?city=bern'

# Send GET request to the API
response = requests.get(url)
data = response.json()  # Parse the JSON response
df = pd.DataFrame(data['aarepast']) # Get the past flow and water temperature and save it in a data frame
df['timestamp'] = pd.to_datetime(df['timestamp'], unit='s') # change datetime
df
# Out:
#               timestamp  ...  temperature
# 0   2025-08-19 14:00:00  ...        21.25
# 1   2025-08-19 14:10:00  ...        21.28
# 2   2025-08-19 14:20:00  ...        21.31
# 3   2025-08-19 14:30:00  ...        21.34
# 4   2025-08-19 14:40:00  ...        21.35
# ..                  ...  ...          ...
# 277 2025-08-21 13:00:00  ...        19.77
# 278 2025-08-21 13:10:00  ...        19.78
# 279 2025-08-21 13:20:00  ...        19.80
# 280 2025-08-21 13:30:00  ...        19.81
# 281 2025-08-21 13:40:00  ...        19.82
#
# [282 rows x 3 columns]

# %% [markdown]
# Get a rough overview of the data set we obtained

# %%
df.describe()
# Out:
#                            timestamp  ...  temperature
# count                            282  ...    280.00000
# mean   2025-08-20 13:54:57.872340480  ...     20.09500
# min              2025-08-19 14:00:00  ...     18.58000
# 25%              2025-08-20 02:12:30  ...     19.51750
# 50%              2025-08-20 13:55:00  ...     20.12500
# 75%              2025-08-21 01:57:30  ...     20.77750
# max              2025-08-21 13:40:00  ...     21.36000
# std                              NaN  ...      0.76707
#
# [8 rows x 3 columns]

# %% [markdown]
# Plot water temperature.

# %%
import matplotlib.pyplot as plt
df.plot(x='timestamp', y='temperature', kind='line')
plt.show()

# %% [markdown]
# Let us now compare the aare temperature in Bern with the air temperature and percipitation. You can find the documentation of this API here: https://open-meteo.com/en/docs

# %%
# URL of weather api
url = 'https://api.open-meteo.com/v1/forecast?latitude=52.52&longitude=13.41&past_days=10&hourly=temperature_2m,precipitation'

# Send GET request to the API
response = requests.get(url)
data = response.json()  # Parse the JSON response
df2 = pd.DataFrame(data['hourly']) # Get the past flow and water temperature and save it in a data frame
df2['time'] = pd.to_datetime(df2['time']) # change datetime
df2
# Out:
#                    time  ...  precipitation
# 0   2025-08-11 00:00:00  ...            0.0
# 1   2025-08-11 01:00:00  ...            0.0
# 2   2025-08-11 02:00:00  ...            0.0
# 3   2025-08-11 03:00:00  ...            0.0
# 4   2025-08-11 04:00:00  ...            0.0
# ..                  ...  ...            ...
# 403 2025-08-27 19:00:00  ...            0.0
# 404 2025-08-27 20:00:00  ...            0.0
# 405 2025-08-27 21:00:00  ...            0.0
# 406 2025-08-27 22:00:00  ...            0.0
# 407 2025-08-27 23:00:00  ...            0.0
#
# [408 rows x 3 columns]

# %% [markdown]
# Let's also plot the temperature.

# %%
df2.plot(x='time', y='temperature_2m', kind='line')
plt.show()

# %% [markdown]
# We can see that the two timeseries have a different scope. Let us thus only take the timepoints that occur in both time series.

# %%
df2.rename(columns={'time': 'timestamp'}, inplace=True)
df_new = pd.merge(df, df2, on='timestamp', how='left') # we use a left join to have the fine timegrid from the aare data
Data = df_new.dropna()
Data
# Out:
#               timestamp  ...  precipitation
# 0   2025-08-19 14:00:00  ...            0.0
# 6   2025-08-19 15:00:00  ...            0.0
# 12  2025-08-19 16:00:00  ...            0.0
# 18  2025-08-19 17:00:00  ...            0.0
# 24  2025-08-19 18:00:00  ...            0.0
# 30  2025-08-19 19:00:00  ...            0.0
# 36  2025-08-19 20:00:00  ...            0.0
# 42  2025-08-19 21:00:00  ...            0.0
# 48  2025-08-19 22:00:00  ...            0.0
# 57  2025-08-20 00:00:00  ...            0.0
# 63  2025-08-20 01:00:00  ...            0.0
# 69  2025-08-20 02:00:00  ...            0.0
# 75  2025-08-20 03:00:00  ...            0.0
# 81  2025-08-20 04:00:00  ...            0.0
# 87  2025-08-20 05:00:00  ...            0.0
# 93  2025-08-20 06:00:00  ...            0.0
# 99  2025-08-20 07:00:00  ...            0.0
# 105 2025-08-20 08:00:00  ...            0.0
# 111 2025-08-20 09:00:00  ...            0.0
# 117 2025-08-20 10:00:00  ...            0.0
# 123 2025-08-20 11:00:00  ...            0.0
# 129 2025-08-20 12:00:00  ...            0.0
# 135 2025-08-20 13:00:00  ...            0.0
# 141 2025-08-20 14:00:00  ...            0.0
# 147 2025-08-20 15:00:00  ...            0.0
# 153 2025-08-20 16:00:00  ...            0.0
# 159 2025-08-20 17:00:00  ...            0.0
# 165 2025-08-20 18:00:00  ...            0.0
# 171 2025-08-20 19:00:00  ...            0.0
# 177 2025-08-20 20:00:00  ...            0.0
# 183 2025-08-20 21:00:00  ...            0.0
# 189 2025-08-20 22:00:00  ...            0.0
# 199 2025-08-21 00:00:00  ...            0.0
# 205 2025-08-21 01:00:00  ...            0.0
# 211 2025-08-21 02:00:00  ...            0.0
# 217 2025-08-21 03:00:00  ...            0.0
# 223 2025-08-21 04:00:00  ...            0.0
# 229 2025-08-21 05:00:00  ...            0.0
# 235 2025-08-21 06:00:00  ...            0.0
# 241 2025-08-21 07:00:00  ...            0.0
# 247 2025-08-21 08:00:00  ...            0.0
# 253 2025-08-21 09:00:00  ...            0.0
# 259 2025-08-21 10:00:00  ...            0.0
# 265 2025-08-21 11:00:00  ...            0.0
# 271 2025-08-21 12:00:00  ...            0.0
# 277 2025-08-21 13:00:00  ...            0.0
#
# [46 rows x 5 columns]

# %% [markdown]
# Now let us plot the air and water temperature to see whether there is a correlation.

# %%
plt.figure(figsize=(10, 6))  # Optional: Adjust the figure size
plt.plot(df_new['timestamp'], df_new['temperature'], label="water temperature")
plt.plot(df_new['timestamp'], df_new['temperature_2m'], label="air temperature", marker='o' )
# Customize the plot
plt.xlabel('datetime')
plt.ylabel('Temperature')
plt.title('Aare and Air Temperature in Bern')
plt.legend()
plt.show()

# %% [markdown]
# **Possible further exercise or project for Module 1 and 2**
#
# Find some colleague who can get the historical data (knows how to use the API) out of https://aareguru.existenz.ch/. Bring all data into one data frame. Look for correlations, averages (per month, per year ...). Combine the data with weather data, e.g. the wind on the Thun lake. For the Model 2 project, try to make a linear regression model predicting the Aare temperature.

# %% [markdown]
# ## 3.2 Get pictures (or files) from webpages
#
# Get 3 pictures from a webserver with the Image module and show it directly.

# %%
import requests
import pandas as pd
from datetime import datetime
from IPython.display import Image, display

# URL of weather api
url = ' https://dog.ceo/api/breed/hound/images'

# Send GET request to the API
response = requests.get(url)
data = response.json()
dog_images = pd.DataFrame(data)
for i in range(1,4):
    url = dog_images.iat[i,0]
    img = Image(url)
    display(img)

# %% [markdown]
# ### Exercise
# There is an API giving some cat pictures (https://api.thecatapi.com/v1/images/search?limit=10). Can you adapt the above code to obtain pictures of cats?

# %%
import requests
import pandas as pd
from datetime import datetime
from IPython.display import Image, display

# URL of cat api
url = 'https://api.thecatapi.com/v1/images/search?limit=10'

# Send GET request to the API
response = requests.get(url)
data = response.json() # Parse the JSON response

# The response is a list of dictionaries, where each dictionary contains image information
# We can directly iterate through this list
for cat_info in data:
    url = cat_info['url']  # Get the image URL from the dictionary
    img = Image(url)
    display(img)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ## 3.3 Scrape Webpages (html scraping)
#
# There are several billion online websites. With python you can easily read and parse this data if you have the links. Since pages are linked, one can in principle unnest probably all internet for webpages.
#
# In Python there is a library https://www.crummy.com/software/BeautifulSoup/bs4/doc/ for pulling data out of html and xml pages. We don't practise that library here, however, if you at some point deal with a lot of html, you may want to use it.
#
# Here we get the email adresses from a contact page of a website.

# %%
from urllib.request import urlopen
import numpy as np
import pandas as pd

startlink = "https://www.zeilenwerk.ch/agentur"
f = urlopen(startlink)
myfile = f.read()
str(myfile)
lines = str(myfile).split(' ')
addresses = []
for line in lines:
    if 'mailto' in line:
        tmp = np.array(line.split('"'))
        if len(tmp)== 3:
          tmp2 = np.array(tmp[1].split(':'))
          addresses.append(tmp2[1])
df_addrs = pd.DataFrame(addresses,columns=['Adresses'])
df_addrs
# Out:
#                         Adresses
# 0    tobias.feller@zeilenwerk.ch
# 1            cyril@zeilenwerk.ch
# 2           andrea@zeilenwerk.ch
# 3          janosch@zeilenwerk.ch
# 4              urs@zeilenwerk.ch
# 5          corinne@zeilenwerk.ch
# 6          jessica@zeilenwerk.ch
# 7            mario@zeilenwerk.ch
# 8         johannes@zeilenwerk.ch
# 9       alessandra@zeilenwerk.ch
# 10         raphael@zeilenwerk.ch
# 11           dario@zeilenwerk.ch
# 12          merlin@zeilenwerk.ch
# 13            jaro@zeilenwerk.ch
# 14    martin.buchs@zeilenwerk.ch
# 15         manuela@zeilenwerk.ch
# 16  lukas.lazarcik@zeilenwerk.ch
# 17          tobias@zeilenwerk.ch
# 18           hello@zeilenwerk.ch

# %% [markdown]
# The above code is not optimal as you have probably seen. Lets use regular expressions instead (from StackOverflow). Regular expressions are a bit geeky, but very powerful and great fun. If you don't wan't to learn them, you mostly find the expression you want by googling.

# %%
import re # the regular expression module
startlink = "https://www.zeilenwerk.ch/agentur"
f = urlopen(startlink)
html = f.read()
# Extract email addresses
reobj = re.compile(r"\b[A-Z0-9._%+-]+@[A-Z0-9.-]+\.[A-Z]{2,6}\b", re.IGNORECASE)
print(re.findall(reobj, html.decode('utf-8')))
# Out:
# ['andrea@zeilenwerk.ch', 'andrea@zeilenwerk.ch', 'lukas.lazarcik@zeilenwerk.ch', 'lukas.lazarcik@zeilenwerk.ch', 'alessandra@zeilenwerk.ch', 'alessandra@zeilenwerk.ch', 'dario@zeilenwerk.ch', 'dario@zeilenwerk.ch', 'manuela@zeilenwerk.ch', 'manuela@zeilenwerk.ch', 'urs@zeilenwerk.ch', 'urs@zeilenwerk.ch', 'jaro@zeilenwerk.ch', 'jaro@zeilenwerk.ch', 'tobias.feller@zeilenwerk.ch', 'tobias.feller@zeilenwerk.ch', 'cyril@zeilenwerk.ch', 'cyril@zeilenwerk.ch', 'johannes@zeilenwerk.ch', 'johannes@zeilenwerk.ch', 'mario@zeilenwerk.ch', 'mario@zeilenwerk.ch', 'raphael@zeilenwerk.ch', 'raphael@zeilenwerk.ch', 'corinne@zeilenwerk.ch', 'corinne@zeilenwerk.ch', 'jessica@zeilenwerk.ch', 'jessica@zeilenwerk.ch', 'merlin@zeilenwerk.ch', 'merlin@zeilenwerk.ch', 'martin.buchs@zeilenwerk.ch', 'martin.buchs@zeilenwerk.ch', 'janosch@zeilenwerk.ch', 'janosch@zeilenwerk.ch', 'tobias@zeilenwerk.ch', 'tobias@zeilenwerk.ch', 'hello@zeilenwerk.ch', 'hello@zeilenwerk.ch', 'hello@zeilenwerk.ch', 'hello@zeilenwerk.ch', 'andrea@zeilenwerk.ch', 'andrea@zeilenwerk.ch', 'lukas.lazarcik@zeilenwerk.ch', 'lukas.lazarcik@zeilenwerk.ch', 'alessandra@zeilenwerk.ch', 'alessandra@zeilenwerk.ch', 'dario@zeilenwerk.ch', 'dario@zeilenwerk.ch', 'manuela@zeilenwerk.ch', 'manuela@zeilenwerk.ch', 'urs@zeilenwerk.ch', 'urs@zeilenwerk.ch', 'jaro@zeilenwerk.ch', 'jaro@zeilenwerk.ch', 'tobias.feller@zeilenwerk.ch', 'tobias.feller@zeilenwerk.ch', 'cyril@zeilenwerk.ch', 'cyril@zeilenwerk.ch', 'johannes@zeilenwerk.ch', 'johannes@zeilenwerk.ch', 'mario@zeilenwerk.ch', 'mario@zeilenwerk.ch', 'raphael@zeilenwerk.ch', 'raphael@zeilenwerk.ch', 'corinne@zeilenwerk.ch', 'corinne@zeilenwerk.ch', 'jessica@zeilenwerk.ch', 'jessica@zeilenwerk.ch', 'merlin@zeilenwerk.ch', 'merlin@zeilenwerk.ch', 'martin.buchs@zeilenwerk.ch', 'martin.buchs@zeilenwerk.ch', 'janosch@zeilenwerk.ch', 'janosch@zeilenwerk.ch', 'tobias@zeilenwerk.ch', 'tobias@zeilenwerk.ch']

# %% [markdown]
# ### Exercise
#
# Hier a nice little challenge for you. Use the code above (together with a for loop or two) to scrape all webpages of your employer company for public available email addresses and put them into a dataframe :)

# %%
# Write, copy and paste your code here

# %% [markdown]
# ### Tables from webpages
#
# If you or someone else pubslishes data in html tables, it can be collected with pandas quite easily, actually directly without using the urllib module.

# %%
import pandas as pd
link = "https://en.wikipedia.org/wiki/List_of_countries_and_dependencies_by_population"
tables = pd.read_html(link) # Reads the html link from the website
new_data = df.dropna()
new_data
#new_data.head(5)
# Out:
#               timestamp  ...  temperature
# 0   2025-08-19 14:00:00  ...        21.25
# 1   2025-08-19 14:10:00  ...        21.28
# 2   2025-08-19 14:20:00  ...        21.31
# 3   2025-08-19 14:30:00  ...        21.34
# 4   2025-08-19 14:40:00  ...        21.35
# 5   2025-08-19 14:50:00  ...        21.36
# 6   2025-08-19 15:00:00  ...        21.36
# 7   2025-08-19 15:10:00  ...        21.36
# 8   2025-08-19 15:20:00  ...        21.35
# 9   2025-08-19 15:30:00  ...        21.34
# 10  2025-08-19 15:40:00  ...        21.33
# 11  2025-08-19 15:50:00  ...        21.30
# 12  2025-08-19 16:00:00  ...        21.27
# 13  2025-08-19 16:10:00  ...        21.24
# 14  2025-08-19 16:20:00  ...        21.20
# 15  2025-08-19 16:30:00  ...        21.17
# 16  2025-08-19 16:40:00  ...        21.14
# 17  2025-08-19 16:50:00  ...        21.10
# 18  2025-08-19 17:00:00  ...        21.07
# 19  2025-08-19 17:10:00  ...        21.04
# 20  2025-08-19 17:20:00  ...        21.00
# 21  2025-08-19 17:30:00  ...        20.97
# 22  2025-08-19 17:40:00  ...        20.93
# 23  2025-08-19 17:50:00  ...        20.88
# 24  2025-08-19 18:00:00  ...        20.84
# 25  2025-08-19 18:10:00  ...        20.80
# 26  2025-08-19 18:20:00  ...        20.76
# 27  2025-08-19 18:30:00  ...        20.73
# 28  2025-08-19 18:40:00  ...        20.70
# 29  2025-08-19 18:50:00  ...        20.68
# 30  2025-08-19 19:00:00  ...        20.65
# 31  2025-08-19 19:10:00  ...        20.63
# 32  2025-08-19 19:20:00  ...        20.62
# 33  2025-08-19 19:30:00  ...        20.60
# 34  2025-08-19 19:40:00  ...        20.57
# 35  2025-08-19 19:50:00  ...        20.55
# 36  2025-08-19 20:00:00  ...        20.52
# 37  2025-08-19 20:10:00  ...        20.49
# 38  2025-08-19 20:20:00  ...        20.48
# 39  2025-08-19 20:30:00  ...        20.46
# 40  2025-08-19 20:40:00  ...        20.43
# 41  2025-08-19 20:50:00  ...        20.41
# 42  2025-08-19 21:00:00  ...        20.38
# 43  2025-08-19 21:10:00  ...        20.35
# 44  2025-08-19 21:20:00  ...        20.32
# 45  2025-08-19 21:30:00  ...        20.28
# 239 2025-08-21 06:40:00  ...        19.46
# 240 2025-08-21 06:50:00  ...        19.46
# 241 2025-08-21 07:00:00  ...        19.46
# 242 2025-08-21 07:10:00  ...        19.46
# 243 2025-08-21 07:20:00  ...        19.47
# 244 2025-08-21 07:30:00  ...        19.49
# 245 2025-08-21 07:40:00  ...        19.51
# 246 2025-08-21 07:50:00  ...        19.52
# 247 2025-08-21 08:00:00  ...        19.54
# 248 2025-08-21 08:10:00  ...        19.56
# 249 2025-08-21 08:20:00  ...        19.57
# 250 2025-08-21 08:30:00  ...        19.59
# 251 2025-08-21 08:40:00  ...        19.60
# 252 2025-08-21 08:50:00  ...        19.61
# 253 2025-08-21 09:00:00  ...        19.63
# 254 2025-08-21 09:10:00  ...        19.64
# 255 2025-08-21 09:20:00  ...        19.65
# 256 2025-08-21 09:30:00  ...        19.65
# 257 2025-08-21 09:40:00  ...        19.65
# 258 2025-08-21 09:50:00  ...        19.64
# 259 2025-08-21 10:00:00  ...        19.63
# 260 2025-08-21 10:10:00  ...        19.63
# 261 2025-08-21 10:20:00  ...        19.64
# 262 2025-08-21 10:30:00  ...        19.65
# 263 2025-08-21 10:40:00  ...        19.68
# 264 2025-08-21 10:50:00  ...        19.70
# 265 2025-08-21 11:00:00  ...        19.72
# 266 2025-08-21 11:10:00  ...        19.74
# 267 2025-08-21 11:20:00  ...        19.75
# 268 2025-08-21 11:30:00  ...        19.75
# 269 2025-08-21 11:40:00  ...        19.76
# 270 2025-08-21 11:50:00  ...        19.76
# 271 2025-08-21 12:00:00  ...        19.76
# 272 2025-08-21 12:10:00  ...        19.76
# 273 2025-08-21 12:20:00  ...        19.76
# 274 2025-08-21 12:30:00  ...        19.76
# 275 2025-08-21 12:40:00  ...        19.76
# 276 2025-08-21 12:50:00  ...        19.76
# 277 2025-08-21 13:00:00  ...        19.77
# 278 2025-08-21 13:10:00  ...        19.78
# 279 2025-08-21 13:20:00  ...        19.80
# 280 2025-08-21 13:30:00  ...        19.81
# 281 2025-08-21 13:40:00  ...        19.82
#
# [280 rows x 3 columns]

# %% [markdown]
# Which countries have the largest population?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 282 entries, 0 to 281
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   timestamp    282 non-null    datetime64[ns]
#  1   flow         282 non-null    int64
#  2   temperature  280 non-null    float64
# dtypes: datetime64[ns](1), float64(1), int64(1)
# memory usage: 6.7 KB

# %%
s_df = df.iloc[1:,1:3]
pd.set_option(r"display.max_rows", 281)
pd.set_option(r"display.max_columns", 2)
s_df
# Out:
#      flow  temperature
# 1     142        21.28
# 2     142        21.31
# 3     142        21.34
# 4     142        21.35
# 5     142        21.36
# 6     142        21.36
# 7     142        21.36
# 8     142        21.35
# 9     142        21.34
# 10    142        21.33
# 11    142        21.30
# 12    142        21.27
# 13    142        21.24
# 14    142        21.20
# 15    142        21.17
# 16    142        21.14
# 17    142        21.10
# 18    142        21.07
# 19    142        21.04
# 20    142        21.00
# 21    142        20.97
# 22    142        20.93
# 23    142        20.88
# 24    142        20.84
# 25    142        20.80
# 26    142        20.76
# 27    142        20.73
# 28    141        20.70
# 29    142        20.68
# 30    142        20.65
# 31    142        20.63
# 32    142        20.62
# 33    142        20.60
# 34    142        20.57
# 35    142        20.55
# 36    141        20.52
# 37    142        20.49
# 38    142        20.48
# 39    142        20.46
# 40    142        20.43
# 41    142        20.41
# 42    142        20.38
# 43    142        20.35
# 44    142        20.32
# 45    142        20.28
# 46    142        20.25
# 47    142        20.21
# 48    142        20.18
# 49    142        20.14
# 50    142        20.11
# 51    142        20.07
# 52    142        20.03
# 53    142        20.00
# 54    142          NaN
# 55    142        19.94
# 56    142        19.87
# 57    142        19.86
# 58    142        19.84
# 59    142        19.83
# 60    142        19.83
# 61    142        19.82
# 62    142        19.83
# 63    142        19.84
# 64    142        19.85
# 65    142        19.86
# 66    142        19.88
# 67    142        19.90
# 68    142        19.93
# 69    142        19.96
# 70    142        19.99
# 71    142        20.01
# 72    142        20.04
# 73    142        20.06
# 74    142        20.09
# 75    142        20.10
# 76    142        20.12
# 77    142        20.13
# 78    142        20.14
# 79    142        20.15
# 80    142        20.16
# 81    142        20.17
# 82    142        20.18
# 83    142        20.19
# 84    142        20.19
# 85    142        20.20
# 86    142        20.20
# 87    142        20.21
# 88    142        20.21
# 89    142        20.22
# 90    142        20.23
# 91    142        20.25
# 92    142        20.27
# 93    142        20.29
# 94    142        20.31
# 95    142        20.33
# 96    142        20.34
# 97    142        20.36
# 98    142        20.38
# 99    142        20.39
# 100   142        20.41
# 101   142        20.43
# 102   142        20.45
# 103   141        20.48
# 104   141        20.50
# 105   142        20.52
# 106   142        20.54
# 107   142        20.56
# 108   142        20.57
# 109   142        20.60
# 110   142        20.62
# 111   142        20.65
# 112   142        20.68
# 113   141        20.73
# 114   141        20.77
# 115   141        20.81
# 116   141        20.86
# 117   141        20.91
# 118   141        20.97
# 119   141        21.00
# 120   141        20.99
# 121   141        20.98
# 122   141        21.00
# 123   141        21.02
# 124   141        21.05
# 125   141        21.07
# 126   141        21.06
# 127   141        21.06
# 128   141        21.06
# 129   142        21.05
# 130   141        21.05
# 131   141        21.06
# 132   141        21.05
# 133   141        21.05
# 134   142        21.05
# 135   142        21.04
# 136   142        21.03
# 137   142        21.03
# 138   141        21.03
# 139   141        21.03
# 140   141        21.02
# 141   141        21.03
# 142   141        21.04
# 143   141        21.06
# 144   141        21.09
# 145   141        21.11
# 146   141        21.12
# 147   141        21.12
# 148   142        21.11
# 149   142        21.09
# 150   142        21.06
# 151   142        21.03
# 152   143        21.01
# 153   143        20.98
# 154   144        20.96
# 155   145        20.93
# 156   148        20.90
# 157   151        20.86
# 158   156        20.81
# 159   160        20.75
# 160   163        20.69
# 161   164        20.64
# 162   166        20.58
# 163   166        20.52
# 164   165        20.44
# 165   165        20.34
# 166   164        20.22
# 167   163        20.11
# 168   162        20.00
# 169   161        19.90
# 170   160        19.80
# 171   159        19.72
# 172   159        19.65
# 173   158        19.59
# 174   158        19.52
# 175   158        19.45
# 176   158        19.39
# 177   159        19.31
# 178   159        19.24
# 179   159        19.16
# 180   159        19.08
# 181   159        19.01
# 182   159        18.94
# 183   158        18.87
# 184   158        18.82
# 185   157        18.79
# 186   157        18.77
# 187   156        18.75
# 188   156        18.74
# 189   155        18.73
# 190   155        18.72
# 191   154        18.70
# 192   154        18.68
# 193   154        18.66
# 194   154        18.64
# 195   154          NaN
# 196   153        18.61
# 197   153        18.59
# 198   152        18.58
# 199   152        18.60
# 200   152        18.64
# 201   152        18.68
# 202   152        18.72
# 203   152        18.76
# 204   152        18.79
# 205   152        18.83
# 206   152        18.87
# 207   152        18.91
# 208   152        18.96
# 209   152        19.00
# 210   152        19.03
# 211   152        19.06
# 212   152        19.08
# 213   152        19.09
# 214   153        19.11
# 215   153        19.14
# 216   154        19.16
# 217   155        19.17
# 218   156        19.17
# 219   157        19.17
# 220   158        19.17
# 221   159        19.18
# 222   160        19.20
# 223   161        19.23
# 224   161        19.26
# 225   161        19.29
# 226   161        19.31
# 227   161        19.33
# 228   161        19.34
# 229   161        19.35
# 230   161        19.37
# 231   161        19.39
# 232   161        19.42
# 233   162        19.44
# 234   162        19.45
# 235   163        19.46
# 236   165        19.46
# 237   165        19.46
# 238   166        19.46
# 239   167        19.46
# 240   167        19.46
# 241   167        19.46
# 242   167        19.46
# 243   167        19.47
# 244   167        19.49
# 245   167        19.51
# 246   167        19.52
# 247   167        19.54
# 248   167        19.56
# 249   167        19.57
# 250   166        19.59
# 251   167        19.60
# 252   167        19.61
# 253   167        19.63
# 254   167        19.64
# 255   167        19.65
# 256   167        19.65
# 257   167        19.65
# 258   166        19.64
# 259   166        19.63
# 260   167        19.63
# 261   166        19.64
# 262   166        19.65
# 263   166        19.68
# 264   166        19.70
# 265   166        19.72
# 266   166        19.74
# 267   166        19.75
# 268   167        19.75
# 269   167        19.76
# 270   166        19.76
# 271   167        19.76
# 272   166        19.76
# 273   166        19.76
# 274   167        19.76
# 275   167        19.76
# 276   167        19.76
# 277   167        19.77
# 278   167        19.78
# 279   167        19.80
# 280   167        19.81
# 281   167        19.82

# %% [markdown]
# ### Exercise
# Find another interesting table to scrape from Wikipedia and look at it more closely.

# %%
import pandas as pd
url = "https://en.wikipedia.org/wiki/FIFA_World_Cup_records_and_statistics"
tables = pd.read_html(url) # Reads the table from the website
df = pd.set_option(r'display.max_rows',22)
df= pd.set_option(r'display.max_columns', 7)

# %% [markdown]
# ## Some notes and links concerning social Media

# %% [markdown]
# ### 1. Google search
#
# There is are APIs for doing google searches from Python. Hier is one explained.
#
# https://stackoverflow.com/questions/37083058/programmatically-searching-google-in-python-using-custom-search

# %% [markdown]
# ### 2. Twitter
#
# Twitter generates about 500M tweets per day. Thus, data mining on twitter can be interesting.
#
# Note: there are rate limits in the use of the Twitter API, as well as limitations in case you want to provide a downloadable data-set, see:
#
# https://dev.twitter.com/overview/terms/agreement-and-policy
#
# https://dev.twitter.com/rest/public/rate-limiting
#
# Tweepy is one python module with clients for thwe Twitter API.
#
# - https://www.tweepy.org/

# %% [markdown]
# ### 3. Instagram
#
# Largest photo sharing social media platform with 500 million monthly active users, and 95 million pictures and videos uploaded on Instagram daily in 2018 (?).
#
# https://stackoverflow.com/questions/61010431/how-to-start-with-the-instagramapi-in-python
